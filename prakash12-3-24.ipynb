# %%
import requests
# !pip install --upgrade 'library'
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for library: filename=Library-0.0.0-py3-none-any.whl size=2054 sha256=13055af9d756a49e3436ffa83eb0e686c40c68dfe5fc296b2961ce5f5385a8d4
#   Stored in directory: /root/.cache/pip/wheels/e0/71/7d/b0e29b944e43374597cd4e3b88c85197001c9bfcd5dce191f4
# Successfully built library
# ...

# %%
r = requests.get('https://www.royalenfield.com/in/en/motorcycles/continental-gt/')
r
# Out:
# <Response [200]>

# %%
r.status_code
# Out:
# 406

# %%
url = 'https://www.royalenfield.com/in/en/motorcycles/continental-gt/'

headers={'Content-type':'application/json'}

# %%
url
# Out:
# 'https://WWW.romexchange.com/'

# %%
url = 'https://www.royalenfield.com/in/en/motorcycles/continental-gt/'

headers={'User-Agent':'XY','Content-type':'application/json'}
r=requests.get(url,headers=headers)

# %%
r.text
# Out:
# '<!DOCTYPE HTML>\n\n<html lang="en" data-attr-pagePath="/content/royal-enfield/in/en/motorcycles/continental-gt" class="app__html">\n    \n    \n\n        <head cdp-required="true" cdp-model-category="Cafe Racer" cdp-model-code="VLWJ60BS">\n            <meta class="redirectPage" data-redirect="false"/>\n\n        <meta charset="UTF-8"/>\n        <meta name="viewport" content="width=device-width, initial-scale=1, minimum-scale=1, maximum-scale=1, user-scalable=no"/>\n        <meta name="description" content="Royal Enfield Continental GT 650 bike price in India. Check RE Continental GT 650 colours, mileage, images, specifications, reviews and other details."/>\n        <meta name="keywords"/>\n        <meta name="title" content="RE Continental GT 650 Price, Colours, Images &amp; Mileage in India | Royal Enfield"/>\n\n        <title>RE Continental GT 650 Price, Colours, Images &amp; Mileage in India | Royal Enfield</title>\n\n            <link rel="icon" type="image/png" href="/content/
# ...
